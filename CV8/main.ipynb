# %% [markdown]
# ## Imports

# %%
import algorithm, visualization, distances
from classes import Config
from IPython.display import HTML

# %% [markdown]
# ## Configuration

# %%
# Configuration
config: Config = Config(
    num_cities=15,
    num_ants=10,
    num_iterations=200,
    alpha=1.0,
    beta=1.0,
    ep_rate=0.5,
    Q=1,
    distance_method=distances.euclidean_numpy
)

# %% [markdown]
# ## Ant Colony Optimization

# %%
cities, paths = algorithm.ant_colony_optimization(config)

# %% [markdown]
# ## ACO - animated progress visualization

# %%
# Create progress animation
HTML(visualization.visualize_animated_progress(config, cities, paths).to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## ACO - best path visualization

# %%
# Create animation and render to Jupyter inline HTML cell (convert into HTML video)
HTML(visualization.visualize_animated(config, cities, paths[-1]).to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
